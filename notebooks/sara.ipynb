# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
user_results = pd.read_csv("../data/lovoo_v3_users_api-results.csv")

# %%
user_results.shape
# Out:
# (3992, 42)

# %%
user_results.head
# Out:
# <bound method NDFrame.head of      gender genderLooking  age          name  counts_details  counts_pictures  \
# 0         F             M   25         daeni            1.00                4
# 1         F             M   22   italiana 92            0.85                5
# 2         F             M   21       Lauraaa            0.00                4
# 3         F          none   20    Qqkwmdowlo            0.12                3
# 4         F             M   21  schaessie {3            0.15               12
# ...     ...           ...  ...           ...             ...              ...
# 3987      F             M   22        Ser**a            0.85                6
# 3988      F             M   24        Mon**a            1.00                7
# 3989      F             M   20         Fa**y            0.90                4
# 3990      F             M   20         Fa**y            0.90                4
# 3991      F             M   20         Fa**y            0.90                4
#
#       counts_profileVisits  counts_kisses  counts_fans  counts_g  ...  \
# 0                     8279            239            0         3  ...
# 1                      663             13            0         0  ...
# 2                     1369             88            0         2  ...
# 3                    22187           1015            2         3  ...
# 4                    35262           1413            9        12  ...
# ...                    ...            ...          ...       ...  ...
# 3987                  1003             98            0         0  ...
# 3988                  6890            563            0         0  ...
# 3989                  1157             52            1         0  ...
# 3990                  1157             52            1         0  ...
# 3991                  1157             52            1         0  ...
#
#       shareProfileEnabled        lastOnlineDate  lastOnlineTime birthd crypt  \
# 0                       1  2015-04-25T20:43:26Z    1.429995e+09      0   NaN
# 1                       1  2015-04-26T09:19:35Z    1.430040e+09      0   NaN
# 2                       1  2015-04-06T14:24:07Z    1.428330e+09      0   NaN
# 3                       1  2015-04-07T11:21:01Z    1.428406e+09      0   NaN
# 4                       1  2015-04-06T14:25:20Z    1.428330e+09      0   NaN
# ...                   ...                   ...             ...    ...   ...
# 3987                    1  2015-04-05T07:13:49Z    1.428218e+09      0   1.0
# 3988                    1  2015-04-19T11:00:59Z    1.429441e+09      0   1.0
# 3989                    1  2015-04-19T08:37:52Z    1.429433e+09      0   1.0
# 3990                    1  2015-04-19T08:37:52Z    1.429433e+09      0   1.0
# 3991                    1  2015-04-19T08:37:52Z    1.429433e+09      0   1.0
#
#                                     freetext  \
# 0     Nur tote Fisch schwimmen mit dem Strom
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 3987                                     NaN
# 3988                                     NaN
# 3989                                     NaN
# 3990                                     NaN
# 3991                                     NaN
#
#                                             whazzup  \
# 0           Nur tote fische schwimmen mit dem strom
# 1                                     Primaveraaa<3
# 2                                               NaN
# 3          Je pense donc je suis.  Instagram quedev
# 4                             Instagram: JESSSIESCH
# ...                                             ...
# 3987                               Fiesta and sport
# 3988  tous des créatures de Dieu, y'a pas de VIP!!!
# 3989                                            NaN
# 3990                                            NaN
# 3991                                            NaN
#
#                                                  userId  \
# 0                              4e3842f79b70e7ea57000064
# 1                              4e3d34bf5d2bce7b160006a3
# 2                              4ec96c090dc82cb25d00000a
# 3                              4eef8b81ebf2c8f64000000c
# 4                              4ef3cc5aa9d0b3d07d000017
# ...                                                 ...
# 3987  CRYu9vQnJ8lHU2pVpimKJGIyTHqR73rAu8hg21rtn340Ys...
# 3988  CRYuikFTcdFDsGDJugu3PyvSonM1LYwyviJXvZBUayBMgI...
# 3989  CRYv9Qg5MTSHaqrTK2CMe9cPRNACAFdYDi7BEgoQTyljzz...
# 3990  CRYwD9ZmbjDXJu8li2DPXI0UseBJt2lovQBWnbKcGDVVcs...
# 3991  CRYy3Jyp0eCGRSc1WeQQOIYKh3KP6JnmWUeJRLnFXhLt5r...
#
#                              pictureId  isSystemProfile
# 0             55303fc3160ba0eb728b4575              NaN
# 1             552e7b61c66da10d1e8b4c82              NaN
# 2             54a584ecc56da128638b4674              NaN
# 3             54c92738076ea1b5338b4735              NaN
# 4             54e1a6f6c76da135748b4a3a              NaN
# ...                                ...              ...
# 3987  405009d5e3983c4cd863ae43fd6356a0              NaN
# 3988  7e0ddbdb1bd293c96d4a5ec5d0466923              NaN
# 3989  768ddd66fd1df8a05c2f27505eb1c710              NaN
# 3990  768ddd66fd1df8a05c2f27505eb1c710              NaN
# 3991  768ddd66fd1df8a05c2f27505eb1c710              NaN
#
# [3992 rows x 42 columns]>

# %%
user_results.describe
# Out:
# <bound method NDFrame.describe of      gender genderLooking  age          name  counts_details  counts_pictures  \
# 0         F             M   25         daeni            1.00                4
# 1         F             M   22   italiana 92            0.85                5
# 2         F             M   21       Lauraaa            0.00                4
# 3         F          none   20    Qqkwmdowlo            0.12                3
# 4         F             M   21  schaessie {3            0.15               12
# ...     ...           ...  ...           ...             ...              ...
# 3987      F             M   22        Ser**a            0.85                6
# 3988      F             M   24        Mon**a            1.00                7
# 3989      F             M   20         Fa**y            0.90                4
# 3990      F             M   20         Fa**y            0.90                4
# 3991      F             M   20         Fa**y            0.90                4
#
#       counts_profileVisits  counts_kisses  counts_fans  counts_g  ...  \
# 0                     8279            239            0         3  ...
# 1                      663             13            0         0  ...
# 2                     1369             88            0         2  ...
# 3                    22187           1015            2         3  ...
# 4                    35262           1413            9        12  ...
# ...                    ...            ...          ...       ...  ...
# 3987                  1003             98            0         0  ...
# 3988                  6890            563            0         0  ...
# 3989                  1157             52            1         0  ...
# 3990                  1157             52            1         0  ...
# 3991                  1157             52            1         0  ...
#
#       shareProfileEnabled        lastOnlineDate  lastOnlineTime birthd crypt  \
# 0                       1  2015-04-25T20:43:26Z    1.429995e+09      0   NaN
# 1                       1  2015-04-26T09:19:35Z    1.430040e+09      0   NaN
# 2                       1  2015-04-06T14:24:07Z    1.428330e+09      0   NaN
# 3                       1  2015-04-07T11:21:01Z    1.428406e+09      0   NaN
# 4                       1  2015-04-06T14:25:20Z    1.428330e+09      0   NaN
# ...                   ...                   ...             ...    ...   ...
# 3987                    1  2015-04-05T07:13:49Z    1.428218e+09      0   1.0
# 3988                    1  2015-04-19T11:00:59Z    1.429441e+09      0   1.0
# 3989                    1  2015-04-19T08:37:52Z    1.429433e+09      0   1.0
# 3990                    1  2015-04-19T08:37:52Z    1.429433e+09      0   1.0
# 3991                    1  2015-04-19T08:37:52Z    1.429433e+09      0   1.0
#
#                                     freetext  \
# 0     Nur tote Fisch schwimmen mit dem Strom
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 3987                                     NaN
# 3988                                     NaN
# 3989                                     NaN
# 3990                                     NaN
# 3991                                     NaN
#
#                                             whazzup  \
# 0           Nur tote fische schwimmen mit dem strom
# 1                                     Primaveraaa<3
# 2                                               NaN
# 3          Je pense donc je suis.  Instagram quedev
# 4                             Instagram: JESSSIESCH
# ...                                             ...
# 3987                               Fiesta and sport
# 3988  tous des créatures de Dieu, y'a pas de VIP!!!
# 3989                                            NaN
# 3990                                            NaN
# 3991                                            NaN
#
#                                                  userId  \
# 0                              4e3842f79b70e7ea57000064
# 1                              4e3d34bf5d2bce7b160006a3
# 2                              4ec96c090dc82cb25d00000a
# 3                              4eef8b81ebf2c8f64000000c
# 4                              4ef3cc5aa9d0b3d07d000017
# ...                                                 ...
# 3987  CRYu9vQnJ8lHU2pVpimKJGIyTHqR73rAu8hg21rtn340Ys...
# 3988  CRYuikFTcdFDsGDJugu3PyvSonM1LYwyviJXvZBUayBMgI...
# 3989  CRYv9Qg5MTSHaqrTK2CMe9cPRNACAFdYDi7BEgoQTyljzz...
# 3990  CRYwD9ZmbjDXJu8li2DPXI0UseBJt2lovQBWnbKcGDVVcs...
# 3991  CRYy3Jyp0eCGRSc1WeQQOIYKh3KP6JnmWUeJRLnFXhLt5r...
#
#                              pictureId  isSystemProfile
# 0             55303fc3160ba0eb728b4575              NaN
# 1             552e7b61c66da10d1e8b4c82              NaN
# 2             54a584ecc56da128638b4674              NaN
# 3             54c92738076ea1b5338b4735              NaN
# 4             54e1a6f6c76da135748b4a3a              NaN
# ...                                ...              ...
# 3987  405009d5e3983c4cd863ae43fd6356a0              NaN
# 3988  7e0ddbdb1bd293c96d4a5ec5d0466923              NaN
# 3989  768ddd66fd1df8a05c2f27505eb1c710              NaN
# 3990  768ddd66fd1df8a05c2f27505eb1c710              NaN
# 3991  768ddd66fd1df8a05c2f27505eb1c710              NaN
#
# [3992 rows x 42 columns]>

# %%
user_results.isnull().sum()
# Out:
# gender                       0
# genderLooking                0
# age                          0
# name                         0
# counts_details               0
# counts_pictures              0
# counts_profileVisits         0
# counts_kisses                0
# counts_fans                  0
# counts_g                     0
# flirtInterests_chat          0
# flirtInterests_friends       0
# flirtInterests_date          0
# country                      0
# city                       287
# location                    13
# distance                    46
# isFlirtstar                  0
# isHighlighted                0
# isInfluencer                 0
# isMobile                     0
# isNew                        0
# isOnline                     0
# isVip                        0
# lang_count                   0
# lang_fr                      0
# lang_en                      0
# lang_de                      0
# lang_it                      0
# lang_es                      0
# lang_pt                      0
# verified                     0
# shareProfileEnabled          0
# lastOnlineDate               1
# lastOnlineTime               1
# birthd                       0
# crypt                     3946
# freetext                  3879
# whazzup                   1593
# userId                       0
# pictureId                   91
# isSystemProfile           3990
# dtype: int64

# %%
user_results_filtered = user_results.drop(["city", "location", "distance", "whazzup", "pictureId", "isSystemProfile"], axis=1)
print (user_results_filtered)
# Out:
#      gender genderLooking  age          name  counts_details  counts_pictures  \
# 0         F             M   25         daeni            1.00                4
# 1         F             M   22   italiana 92            0.85                5
# 2         F             M   21       Lauraaa            0.00                4
# 3         F          none   20    Qqkwmdowlo            0.12                3
# 4         F             M   21  schaessie {3            0.15               12
# ...     ...           ...  ...           ...             ...              ...
# 3987      F             M   22        Ser**a            0.85                6
# 3988      F             M   24        Mon**a            1.00                7
# 3989      F             M   20         Fa**y            0.90                4
# 3990      F             M   20         Fa**y            0.90                4
# 3991      F             M   20         Fa**y            0.90                4
#
#       counts_profileVisits  counts_kisses  counts_fans  counts_g  ...  \
# 0                     8279            239            0         3  ...
# 1                      663             13            0         0  ...
# 2                     1369             88            0         2  ...
# 3                    22187           1015            2         3  ...
# 4                    35262           1413            9        12  ...
# ...                    ...            ...          ...       ...  ...
# 3987                  1003             98            0         0  ...
# 3988                  6890            563            0         0  ...
# 3989                  1157             52            1         0  ...
# 3990                  1157             52            1         0  ...
# 3991                  1157             52            1         0  ...
#
#       lang_es  lang_pt  verified shareProfileEnabled        lastOnlineDate  \
# 0       False    False         0                   1  2015-04-25T20:43:26Z
# 1       False    False         0                   1  2015-04-26T09:19:35Z
# 2       False    False         0                   1  2015-04-06T14:24:07Z
# 3       False    False         0                   1  2015-04-07T11:21:01Z
# 4       False    False         0                   1  2015-04-06T14:25:20Z
# ...       ...      ...       ...                 ...                   ...
# 3987    False    False         0                   1  2015-04-05T07:13:49Z
# 3988    False    False         1                   1  2015-04-19T11:00:59Z
# 3989    False    False         0                   1  2015-04-19T08:37:52Z
# 3990    False    False         0                   1  2015-04-19T08:37:52Z
# 3991    False    False         0                   1  2015-04-19T08:37:52Z
#
#       lastOnlineTime  birthd  crypt                                freetext  \
# 0       1.429995e+09       0    NaN  Nur tote Fisch schwimmen mit dem Strom
# 1       1.430040e+09       0    NaN                                     NaN
# 2       1.428330e+09       0    NaN                                     NaN
# 3       1.428406e+09       0    NaN                                     NaN
# 4       1.428330e+09       0    NaN                                     NaN
# ...              ...     ...    ...                                     ...
# 3987    1.428218e+09       0    1.0                                     NaN
# 3988    1.429441e+09       0    1.0                                     NaN
# 3989    1.429433e+09       0    1.0                                     NaN
# 3990    1.429433e+09       0    1.0                                     NaN
# 3991    1.429433e+09       0    1.0                                     NaN
#
#                                                  userId
# 0                              4e3842f79b70e7ea57000064
# 1                              4e3d34bf5d2bce7b160006a3
# 2                              4ec96c090dc82cb25d00000a
# 3                              4eef8b81ebf2c8f64000000c
# 4                              4ef3cc5aa9d0b3d07d000017
# ...                                                 ...
# 3987  CRYu9vQnJ8lHU2pVpimKJGIyTHqR73rAu8hg21rtn340Ys...
# 3988  CRYuikFTcdFDsGDJugu3PyvSonM1LYwyviJXvZBUayBMgI...
# 3989  CRYv9Qg5MTSHaqrTK2CMe9cPRNACAFdYDi7BEgoQTyljzz...
# 3990  CRYwD9ZmbjDXJu8li2DPXI0UseBJt2lovQBWnbKcGDVVcs...
# 3991  CRYy3Jyp0eCGRSc1WeQQOIYKh3KP6JnmWUeJRLnFXhLt5r...
#
# [3992 rows x 36 columns]

# %%
#Relationship between Is Mobile and counts_kisses

#Plot 

plt.figure(figsize=(10, 5))
plt.scatter(user_results_filtered['age'], user_results_filtered['counts_kisses'], color='purple')
plt.title('Relationship between Age and Counts_Kisses')
plt.xlabel('Age')
plt.ylabel('Counts Kisses')

# Make sure all the ages from min to max are shown as ticks
plt.xticks(range(min(user_results_filtered['age']), max(user_results_filtered['age']) + 1))

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

plt.show()

# %%
corr_age_counts_kiss = user_results['age'].corr(user_results['counts_kisses'])
print (corr_age_counts_kiss)
# Out:
# -0.05753781825924586

# %%
#Relationship between Number of Fans and Counts_Kisses

#Plot 

plt.figure(figsize=(10, 5))
plt.scatter(user_results_filtered["counts_fans"], user_results_filtered["counts_kisses"], alpha=0.6, color='purple')
plt.title("Relationship between Number of Fans and Counts_Kisses")
plt.xlabel("Counts of Fans")
plt.ylabel("Counts of Kisses")
plt.grid(True)
plt.show()

# %%
corr_counts_fans_counts_kiss = user_results['counts_fans'].corr(user_results['counts_kisses'])
print (corr_counts_fans_counts_kiss)
# Out:
# 0.1255315894084899

# %%
#Relationship between Country and Count_Kisses
#Plot
plt.figure(figsize=(15, 7))
plt.bar(user_results_filtered['country'], user_results_filtered['counts_kisses'], color='purple')
plt.title('Relationship between Country and Counts_Kisses')
plt.xlabel('Country')
plt.ylabel('Counts Kisses')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

plt.show()

# %%
#Relationship between Language Count and Counts Kisses

#Plot

plt.figure(figsize=(15, 6))
plt.bar(user_results_filtered['lang_count'], user_results_filtered['counts_kisses'], color='purple')
plt.title('Relationship between Language Count and Counts_Kisses')
plt.xlabel('Language Count')
plt.ylabel('Counts Kisses')

# Set x-ticks based on lang_count values
plt.xticks(user_results_filtered['lang_count'], rotation=45)

plt.show()
