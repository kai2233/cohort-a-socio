# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
date_match = pd.read_csv("../data/lovoo_v3_users_api-results.csv")

# %%
date_match.value_counts("flirtInterests_friends").plot.bar()
# Out:
# <Axes: xlabel='flirtInterests_friends'>

# %%
date_match.value_counts("flirtInterests_date").plot.bar()
# Out:
# <Axes: xlabel='flirtInterests_date'>
