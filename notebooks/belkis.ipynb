# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
matches = pd.read_csv("../data/lovoo_v3_users_api-results.csv")

# %%
matches.head(20)
# Out:
#    gender genderLooking  age           name  counts_details  counts_pictures  \
# 0       F             M   25          daeni            1.00                4
# 1       F             M   22    italiana 92            0.85                5
# 2       F             M   21        Lauraaa            0.00                4
# 3       F          none   20     Qqkwmdowlo            0.12                3
# 4       F             M   21   schaessie {3            0.15               12
# 5       F             M   24       Baby dee            0.81               18
# 6       F          none   24           Anna            0.65               13
# 7       F             M   23     Feelinchen            0.81                6
# 8       F             M   20        chantal            0.88               14
# 9       F             M   24       rina1990            0.81                1
# 10      F             M   22       anniwhat            0.54                3
# ...

# %%
sns.lineplot(x= matches["counts_pictures"] , y=matches["counts_profileVisits"])
# Out:
# <Axes: xlabel='counts_pictures', ylabel='counts_profileVisits'>

# %%
matches[["counts_pictures","counts_profileVisits"]].corr()
# Out:
#                       counts_pictures  counts_profileVisits
# counts_pictures              1.000000              0.417991
# counts_profileVisits         0.417991              1.000000

# %%
sns.barplot(x= matches["counts_pictures"] , y=matches["counts_kisses"])
# Out:
# <Axes: xlabel='counts_pictures', ylabel='counts_kisses'>
